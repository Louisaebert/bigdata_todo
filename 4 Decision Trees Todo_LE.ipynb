# %%
# import symbolic capability to Python
from sympy import *
# print things all pretty
from sympy.abc import *
from sympy.plotting import plot
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display
init_printing()

# %% [markdown]
# # Exercise
#
# You have a dataset with $m$ binary columns and $n$ rows. A given decision tree has the depth $d$.
#
# ## Questions:
# 1. How many different decision trees with depth $d=1$ are possible for a dataset with $m$ binary columns and $n$ rows?
# 2. How many different decision trees with depth $d=2$ are possible for a dataset with $m$ binary columns and $n$ rows?
# 3. How many different decision trees with depth $d=3$ are possible for a dataset with $m$ binary columns and $n$ rows?
# 4. How many different decision trees with depth $d=4$ are possible for a dataset with $m$ binary columns and $n$ rows?
# 5. In general, how many different decision trees with depth $d$ are possible for a dataset with $m$ binary columns and $n$ rows?
# 6. How may different decision trees are possible for $m=4$ and $d=4$?
# 7. In general, how many different decision trees of any depth are possible for a dataset with $m$ binary columns and $n$ rows?
# 8. How many decision trees are possible for $m=4$ binary columns?
# 9. There are $10^{80}$ atoms in the universe. What is the value for $m$ so that the number of decision trees is greater than the number of atoms in the universe?
# 10. How many operations (steps) does the naive testing take of all possible decision trees for a dataset with $m$ binary columns and $n$ rows?
# 11. How many operations (steps) does the naive testing take of all possible decision trees for a dataset with $m=3$ binary columns and $n=100$ rows?

# %% [markdown]
# Variables:
# * $n$: number of rows of the data
# * $m$: number of binary columns (attributes) of the data
# * $d$: depth of the decision tree

# %%
m = symbols("m", positive=True, integer=True)
d = symbols("d", positive=True, integer=True)
n = symbols("n", positive=True, integer=True)

# %% [markdown]
# ![grafik.png](attachment:4fe44150-0f24-4b3f-94dc-1ed8866835e8.png)

# %% [markdown]
# ## Answers:
#
# Todo

# %%
# Nodes for Number 1 to 4 & 6: 

depths=[1,2,3,4]
Nr_nodes=[]

for d in depths: 
    Nodes=2**(d+1)-1
    print(Nodes)
    Nr_nodes.append(Nodes)
# Out:
# 3
# 7
# 15
# 31

# %%
print(Nr_nodes)
# Out:
# [3, 7, 15, 31]

# %%
#Number 1 to 5: 
d1=factorial(m)/factorial(m-3)
d2=factorial(m)/factorial(m-7)
d3=factorial(m)/factorial(m-15)
d4=factorial(m)/factorial(m-31)
anyd=factorial(m)/factorial(m-(2**(d+1)-1)) 

# The number of rows does not influence the number of possible trees as long as there is still an entry in every node

# %%
# Number 6: 
factorial(4)
# the number is limited due to the depth of 4, since depth 4 would mean we have 31 nodes, but only 4 elements to use as such
# Out:
# 24

# %%
# Number 7:
factorial(m)
# Generally m! options are possible if the depth is not limited in any way
# Out:
# m!

# %%
# Number 8: 
factorial(4)
# Out:
# 24

# %%
#Number 9: 
greater = Eq(10**80,factorial(m))

# %%
solve(10**80<factorial(m))
# doesn't work... neither with nsolve / solveset
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/sympy/polys/polyutils.py in _parallel_dict_from_expr_if_gens(exprs, opt)
#     210
# --> 211                         monom[indices[base]] = exp
#     212                     except KeyError:
#
# KeyError: factorial(m)
#
# During handling of the above exception, another exception occurred:
#
# PolynomialError                           Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/sympy/solvers/inequalities.py in _solve_inequality(ie, s, linear)
#     814     try:
# --> 815         p = Poly(expr, s)
#     816         if p.degree() == 0:
#
# /opt/anaconda3/lib/python3.8/site-packages/sympy/polys/polytools.py in __new__(cls, rep, *gens, **args)
#     158             else:
# --> 159                 return cls._from_expr(rep, opt)
#     160
#
# ...

# %%
# setting to atoms 

n_f=1
total =1 
while True:
    n_f += 1 
    total *= n_f
    if total > (10**80):
        print("For",n_f,"there are more possible decision trees then atoms")
        break
# Out:
# For 59 there are more possible decision trees then atoms

# %% [markdown]
# #### Number 10:
#  It takes (factorial(m)/factorial(m-(2pow(d+1)-1)))*n operations

# %%
#Number 11:
factorial(3)*100
# Out:
# 600
